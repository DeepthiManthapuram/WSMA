# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepthiManthapuram/WSMA/blob/main/Lemmatization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('wordnet', quiet=True)
nltk.download('punkt_tab', quiet=True)
# Out:
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
text="The children are playing with the toys in the garden."

# %%
words=word_tokenize(text)
words
# Out:
# ['The',
#  'children',
#  'are',
#  'playing',
#  'with',
#  'the',
#  'toys',
#  'in',
#  'the',
#  'garden',
#  '.']

# %%
lemmatized_words=[lemmatizer.lemmatize(word) for word in words]
lemmatized_words
# Out:
# ['The',
#  'child',
#  'are',
#  'playing',
#  'with',
#  'the',
#  'toy',
#  'in',
#  'the',
#  'garden',
#  '.']

# %%
print("original words: ", words)
print("Lemmatized Words: ", lemmatized_words)
# Out:
# original words:  ['The', 'children', 'are', 'playing', 'with', 'the', 'toys', 'in', 'the', 'garden', '.']
# Lemmatized Words:  ['The', 'child', 'are', 'playing', 'with', 'the', 'toy', 'in', 'the', 'garden', '.']
