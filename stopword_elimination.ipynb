# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepthiManthapuram/WSMA/blob/main/stopword_elimination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('stopwords', quiet = True)
nltk.download('punkt_tab', quiet = True)
# Out:
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
text = "This is an example on how to remove stopwords from a text."
words = word_tokenize(text)
words
# Out:
# ['This',
#  'is',
#  'an',
#  'example',
#  'on',
#  'how',
#  'to',
#  'remove',
#  'stopwords',
#  'from',
#  'a',
#  'text',
#  '.']

# %%
stop_words = set(stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
filtered_words = [word for word in words if word.lower() not in stop_words]
filtered_words
# Out:
# ['example', 'remove', 'stopwords', 'text', '.']

# %%
print("Original words: ",words)
print("After stopword removal: ",filtered_words)
# Out:
# Original words:  ['This', 'is', 'an', 'example', 'on', 'how', 'to', 'remove', 'stopwords', 'from', 'a', 'text', '.']
# After stopword removal:  ['example', 'remove', 'stopwords', 'text', '.']
